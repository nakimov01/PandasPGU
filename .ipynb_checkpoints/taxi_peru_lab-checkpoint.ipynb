# %% [markdown]
# -Помещение файла в датафрейм
# -Изменение в рейтинге со значения NaN на float 0.0
# -Удаление лишних колонок со значением 'driver cancel', 'not found', 'rider cancel'

# %%
df.rider_score = df.rider_score. fillna (0)
df.driver_score = df.driver_score. fillna (0)

# %%
import pandas as pd
df = pd.read_csv("taxi_peru.csv", delimiter=';', parse_dates=['start_at', 'end_at'], encoding = "Windows-1251")
df = df[(df.end_state == 'drop off')]
df
# Out:
#                              journey_id                           user_id  \
# 0      23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 4      85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# 5      2254715f0f569e3173ec61f16cbb8341  56772d544fdfa589a020a1ff894a86f7
# 6      12432d83b49393bf25164673212b8295  56772d544fdfa589a020a1ff894a86f7
# 7      2e51db3a8a77aa594aa686ff19fe6036  56772d544fdfa589a020a1ff894a86f7
# ...                                 ...                               ...
# 23105  a7b77e5e6e60dc427d96d8d22ac91032  35e7f74c2fbd27db816811036af892e5
# 23106  4a18ea5737ce0ffecaf20b305a0e2c86  8998bb370b5f0cec43a373adebba0c72
# 23107  f1e4317f2c17991dd90d1cd17ae0d399  5f8a6ffef0ea5df78a8ee890267b60ec
# 23108  1e44c0fd0a266c3719ff30410b257bce  c0ffb6f6cd801004dd8609c12277c2d1
# 23109  7073883383b89ad289e864022150cdd7  c0ffb6f6cd801004dd8609c12277c2d1
#
#                               driver_id                           taxi_id  \
# ...

# %% [markdown]
# df.loc[df['driver_score'] == 0.0, 'driver_score'] = 4.0
# df.loc[df['rider_score'] == 0.0, 'rider_score'] = 4.0
# df

# %% [markdown]
# Сколько уникальных значений такси и водителей имеется в датафрейме

# %%
df.taxi_id.unique().shape
df.driver_id.unique().shape
# Out:
# (166,)

# %% [markdown]
# Подсчет количества водителей и такси на которых они ездили

# %%
a = df.groupby(['driver_id']).agg({'taxi_id':pd.Series.nunique, 'journey_id':'count'})
a.sort_values(by=['journey_id'], ascending=[False])
# Out:
#                                   taxi_id  journey_id
# driver_id
# c814db2127582cf95dea1f74f43127c2        3        1368
# d665fb9f75ef5d9cd0fd89479380ba78        2        1100
# ff5c924e0b630fd7c019a4234059fdf4        2         976
# 406921adcca37705ef527b4246c0cfea        2         937
# ec84a73745199ff840ecafcb924383ad        2         872
# ...                                   ...         ...
# bf0f0845b5094fda2fcdac195eef3511        1           1
# bf0f0845b5094fda2fcdac195ece97ad        1           1
# ab90a1bf4289d96e78d4a47d7cc2cd22        1           1
# af07f9929390d66edf63ab7ee480273c        1           1
# 5c631eab42d9b2426420a89b862a4a0e        1           1
#
# [166 rows x 2 columns]

# %% [markdown]
# Добавление значений в датафрейм new_df из датафрейма df. Переименование значений journey_id, source, start_type

# %%
new_df = df[['journey_id', 'user_id', 'driver_id','rider_score','driver_score', 'source', 'start_type']].rename(columns={'journey_id':'order_id', 'source':'user_platform', 'start_type':'order_type'})
new_df
# Out:
#                                order_id                           user_id  \
# 0      23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 4      85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# 5      2254715f0f569e3173ec61f16cbb8341  56772d544fdfa589a020a1ff894a86f7
# 6      12432d83b49393bf25164673212b8295  56772d544fdfa589a020a1ff894a86f7
# 7      2e51db3a8a77aa594aa686ff19fe6036  56772d544fdfa589a020a1ff894a86f7
# ...                                 ...                               ...
# 23105  a7b77e5e6e60dc427d96d8d22ac91032  35e7f74c2fbd27db816811036af892e5
# 23106  4a18ea5737ce0ffecaf20b305a0e2c86  8998bb370b5f0cec43a373adebba0c72
# 23107  f1e4317f2c17991dd90d1cd17ae0d399  5f8a6ffef0ea5df78a8ee890267b60ec
# 23108  1e44c0fd0a266c3719ff30410b257bce  c0ffb6f6cd801004dd8609c12277c2d1
# 23109  7073883383b89ad289e864022150cdd7  c0ffb6f6cd801004dd8609c12277c2d1
#
#                               driver_id  rider_score  driver_score  \
# ...

# %% [markdown]
# Добавление колонки с общим временем поездки в датафрейм new_df

# %%
from datetime import datetime, timedelta

new_df['travel_time_in_hours'] = (df['end_at']-df['start_at'])

new_df['travel_time_in_hours'] = (new_df['travel_time_in_hours'] / pd.Timedelta(hours=1)).round(2)

new_df['travel_time_in_hours'] = new_df.loc[(new_df['travel_time_in_hours'] > 0.1) & (new_df['travel_time_in_hours'] < 2.0), 'travel_time_in_hours']

new_df
# Out:
#                                order_id                           user_id  \
# 0      23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 4      85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# 5      2254715f0f569e3173ec61f16cbb8341  56772d544fdfa589a020a1ff894a86f7
# 6      12432d83b49393bf25164673212b8295  56772d544fdfa589a020a1ff894a86f7
# 7      2e51db3a8a77aa594aa686ff19fe6036  56772d544fdfa589a020a1ff894a86f7
# ...                                 ...                               ...
# 23105  a7b77e5e6e60dc427d96d8d22ac91032  35e7f74c2fbd27db816811036af892e5
# 23106  4a18ea5737ce0ffecaf20b305a0e2c86  8998bb370b5f0cec43a373adebba0c72
# 23107  f1e4317f2c17991dd90d1cd17ae0d399  5f8a6ffef0ea5df78a8ee890267b60ec
# 23108  1e44c0fd0a266c3719ff30410b257bce  c0ffb6f6cd801004dd8609c12277c2d1
# 23109  7073883383b89ad289e864022150cdd7  c0ffb6f6cd801004dd8609c12277c2d1
#
#                               driver_id  rider_score  driver_score  \
# ...

# %% [markdown]
# Подготовка координат в правильный формат и дальнейшая конвертация из str в float для нахождения растояния поездки

# %%
df['start_lat'] = df['start_lat'].astype(str).str.replace(',', '.')
df['end_lat'] = df['end_lat'].astype(str).str.replace(',', '.')
df['start_lon'] = df['start_lon'].astype(str).str.replace(',', '.')
df['end_lon'] = df['end_lon'].astype(str).str.replace(',', '.')
df[['start_lat', 'end_lat', 'start_lon', 'end_lon', ]]= df[['start_lat', 'end_lat', 'start_lon', 'end_lon', ]].astype(float)
df
# Out:
#                              journey_id                           user_id  \
# 0      23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 4      85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# 5      2254715f0f569e3173ec61f16cbb8341  56772d544fdfa589a020a1ff894a86f7
# 6      12432d83b49393bf25164673212b8295  56772d544fdfa589a020a1ff894a86f7
# 7      2e51db3a8a77aa594aa686ff19fe6036  56772d544fdfa589a020a1ff894a86f7
# ...                                 ...                               ...
# 23105  a7b77e5e6e60dc427d96d8d22ac91032  35e7f74c2fbd27db816811036af892e5
# 23106  4a18ea5737ce0ffecaf20b305a0e2c86  8998bb370b5f0cec43a373adebba0c72
# 23107  f1e4317f2c17991dd90d1cd17ae0d399  5f8a6ffef0ea5df78a8ee890267b60ec
# 23108  1e44c0fd0a266c3719ff30410b257bce  c0ffb6f6cd801004dd8609c12277c2d1
# 23109  7073883383b89ad289e864022150cdd7  c0ffb6f6cd801004dd8609c12277c2d1
#
#                               driver_id                           taxi_id  \
# ...

# %% [markdown]
# Вычисление расстояния по координатам из датафрейма df и создание колонки travel_distance с дальнейшим перемещением в new_df

# %%
import numpy as np
new_df['travel_distance'] = df.apply(lambda df: ((np.sqrt((df['end_lat']-df['start_lat'])**2 + (df['end_lon']-df['start_lon'])**2))*100), axis=1).round(3)
new_df['travel_distance'] = new_df.loc[(new_df['travel_distance'] > 0.00) & (new_df['travel_distance'] < 100.00), 'travel_distance']
new_df
# Out:
#                                order_id                           user_id  \
# 0      23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 4      85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# 5      2254715f0f569e3173ec61f16cbb8341  56772d544fdfa589a020a1ff894a86f7
# 6      12432d83b49393bf25164673212b8295  56772d544fdfa589a020a1ff894a86f7
# 7      2e51db3a8a77aa594aa686ff19fe6036  56772d544fdfa589a020a1ff894a86f7
# ...                                 ...                               ...
# 23105  a7b77e5e6e60dc427d96d8d22ac91032  35e7f74c2fbd27db816811036af892e5
# 23106  4a18ea5737ce0ffecaf20b305a0e2c86  8998bb370b5f0cec43a373adebba0c72
# 23107  f1e4317f2c17991dd90d1cd17ae0d399  5f8a6ffef0ea5df78a8ee890267b60ec
# 23108  1e44c0fd0a266c3719ff30410b257bce  c0ffb6f6cd801004dd8609c12277c2d1
# 23109  7073883383b89ad289e864022150cdd7  c0ffb6f6cd801004dd8609c12277c2d1
#
#                               driver_id  rider_score  driver_score  \
# ...

# %% [markdown]
# Определение лучшего водителя по 4 колонкам(количеству заказов, средняя оценка, сумма часов работы, общее количество пройденных километров)

# %%
best_driver.loc[(best_driver['order_ids_points'] <= 200), 'order_ids_points'] = best_driver['order_ids_points'] * 1.5
best_driver.loc[(best_driver['order_ids_points'] > 200) & (best_driver['order_ids_points'] <= 400), 'order_ids_points'] = best_driver['order_ids_points'] * 2.0
best_driver.loc[(best_driver['order_ids_points'] > 400) & (best_driver['order_ids_points'] <= 600), 'order_ids_points'] = best_driver['order_ids_points'] * 2.5
best_driver.loc[(best_driver['order_ids_points'] > 600) & (best_driver['order_ids_points'] <= 800), 'order_ids_points'] = best_driver['order_ids_points'] * 3
best_driver.loc[(best_driver['order_ids_points'] > 800) & (best_driver['order_ids_points'] <= 1000), 'order_ids_points'] = best_driver['order_ids_points'] * 3.50
best_driver.loc[(best_driver['order_ids_points'] > 1000) & (best_driver['order_ids_points'] <= 2000), 'order_ids_points'] = best_driver['order_ids_points'] * 4

best_driver.loc[(best_driver['driver_score_points'] <= 4.00), 'driver_score_points'] = best_driver['driver_score_points'] * 10
best_driver.loc[(best_driver['driver_score_points'] > 4.01) & (best_driver['driver_score_points'] <= 4.25), 'driver_score_points'] = best_driver['driver_score_points'] * 15
best_driver.loc[(best_driver['driver_score_points'] > 4.26) & (best_driver['driver_score_points'] <= 4.50), 'driver_score_points'] = best_driver['driver_score_points'] * 20
best_driver.loc[(best_driver['driver_score_points'] > 4.51) & (best_driver['driver_score_points'] <= 4.75), 'driver_score_points'] = best_driver['driver_score_points'] * 30
best_driver.loc[(best_driver['driver_score_points'] > 4.76) & (best_driver['driver_score_points'] <= 4.90), 'driver_score_points'] = best_driver['driver_score_points'] * 35
best_driver.loc[(best_driver['driver_score_points'] > 4.91), 'driver_score_points'] = best_driver['driver_score_points'] * 40

best_driver['total_points'] = (best_driver['order_ids_points']+best_driver['driver_score_points']+best_driver['travel_distance_points'])

best_driver.sort_values(by=['total_points'], ascending=[False]).astype(int).head(10)

Sort_query = best_driver.query("`driver_score_points` > 0.0 and `travel_distance_points` < 100 and `travel_distance_points` > 0.0 ")

# %%
a = new_df[['driver_id', 'order_id', 'driver_score', 'travel_distance']].rename(columns={'order_id':'order_ids_points', 'driver_score':'driver_score_points', 'travel_distance':'travel_distance_points'})
c = a.groupby(['driver_id']).agg({'order_ids_points':'count', 'driver_score_points':'mean', "travel_distance_points":'sum'})
best_driver = c.sort_values(by=['order_ids_points', 'driver_score_points', 'travel_distance_points'], ascending=[False, False, False]).round(2)
best_driver.query("`travel_distance_points` < 100 and `travel_distance_points` > 0.0 ")

best_driver.loc[(best_driver['order_ids_points'] <= 200), 'order_ids_points'] = best_driver['order_ids_points'] * 1.5
best_driver.loc[(best_driver['order_ids_points'] > 200) & (best_driver['order_ids_points'] <= 400), 'order_ids_points'] = best_driver['order_ids_points'] * 2.0
best_driver.loc[(best_driver['order_ids_points'] > 400) & (best_driver['order_ids_points'] <= 600), 'order_ids_points'] = best_driver['order_ids_points'] * 2.5
best_driver.loc[(best_driver['order_ids_points'] > 600) & (best_driver['order_ids_points'] <= 800), 'order_ids_points'] = best_driver['order_ids_points'] * 3
best_driver.loc[(best_driver['order_ids_points'] > 800) & (best_driver['order_ids_points'] <= 1000), 'order_ids_points'] = best_driver['order_ids_points'] * 3.50
best_driver.loc[(best_driver['order_ids_points'] > 1000) & (best_driver['order_ids_points'] <= 1500), 'order_ids_points'] = best_driver['order_ids_points'] * 4

best_driver.loc[(best_driver['driver_score_points'] <= 4.00), 'driver_score_points'] = best_driver['driver_score_points'] * 10
best_driver.loc[(best_driver['driver_score_points'] > 4.01) & (best_driver['driver_score_points'] <= 4.25), 'driver_score_points'] = best_driver['driver_score_points'] * 15
best_driver.loc[(best_driver['driver_score_points'] > 4.26) & (best_driver['driver_score_points'] <= 4.50), 'driver_score_points'] = best_driver['driver_score_points'] * 20
best_driver.loc[(best_driver['driver_score_points'] > 4.51) & (best_driver['driver_score_points'] <= 4.75), 'driver_score_points'] = best_driver['driver_score_points'] * 30
best_driver.loc[(best_driver['driver_score_points'] > 4.76) & (best_driver['driver_score_points'] <= 4.90), 'driver_score_points'] = best_driver['driver_score_points'] * 35
best_driver.loc[(best_driver['driver_score_points'] > 4.91), 'driver_score_points'] = best_driver['driver_score_points'] * 40

best_driver['total_points'] = (best_driver['order_ids_points']+best_driver['driver_score_points']+best_driver['travel_distance_points'])

best_driver.sort_values(by=['total_points'], ascending=[False]).head(10)

best_driver
# Out:
#                                   order_ids_points  driver_score_points  \
# driver_id
# c814db2127582cf95dea1f74f43127c2            5472.0               2538.0
# d665fb9f75ef5d9cd0fd89479380ba78            4400.0               1576.0
# ff5c924e0b630fd7c019a4234059fdf4            3416.0               1528.0
# 406921adcca37705ef527b4246c0cfea            3279.5               2424.0
# ec84a73745199ff840ecafcb924383ad            3052.0               1516.0
# ...                                            ...                  ...
# 5c631eab42d9b2426420a89b862a4a0e               1.5                  NaN
# bf0f0845b5094fda2fcdac195eef3511               1.5                  NaN
# ab90a1bf4289d96e78d4a47d7cc2cd22               1.5                  NaN
# 29c460e9d44ae084d4631c5ade4ec8a8               1.5                  NaN
# 5c631eab42d9b2426420a89b862a6111               1.5                  NaN
#
#                                   travel_distance_points  total_points
# driver_id
# ...

# %%
a = new_df.groupby(['driver_id']).agg({'order_id':'count', 'rider_score':'mean', 'travel_distance':'sum'})
a.sort_values(by=['order_id', 'rider_score', 'travel_distance'], ascending=[False,False,False]).round(2).head(20)
# Out:
#                                   order_id  rider_score  travel_distance
# driver_id
# c814db2127582cf95dea1f74f43127c2      1368         4.97          6597.40
# d665fb9f75ef5d9cd0fd89479380ba78      1100         4.95          6129.79
# ff5c924e0b630fd7c019a4234059fdf4       976         4.50          4301.72
# 406921adcca37705ef527b4246c0cfea       937         4.93          4768.40
# ec84a73745199ff840ecafcb924383ad       872         4.92          4650.08
# ab581e277813d5d9ff98d03b1c96a13f       762         4.82          3692.48
# 406921adcca37705ef527b4246bbbff5       650         4.85          3426.82
# 40187316352d2c03ddc19e9c8ad7c514       565         4.69          2823.97
# e84fda9c5df33f03c89b6923c361fb35       546         4.92          3132.59
# d04f1a596fe4a582f48e6eb2f9e8f617       545         4.20          3138.31
# b66c43e298753a3d39220e53008a4325       500         4.99          2830.03
# ae06c34243f741e203e97c48ebcbd9da       480         4.93          2425.84
# ...

# %%
best_driver = best_driver.sort_values(by=['total_points'], ascending=[False]).head(11)
sns.barplot(x = best_driver.total_points, y = best_driver.index , data = best_driver)
# Out:
# <Axes: xlabel='total_points', ylabel='driver_id'>

# %% [markdown]
# Определение лучшего пользователя по 3 колонкам(количеству поездок, средняя оценка водителем, общее количество километров в поездках)

# %%
a = new_df[['user_id', 'order_id', 'rider_score', 'travel_distance']].rename(columns={'order_id':'order_ids_points', 'rider_score':'rider_score_points', 'travel_distance':'travel_distance_points'})
c = a.groupby(['user_id']).agg({'order_ids_points':'count', 'rider_score_points':'mean', "travel_distance_points":'sum'})
best_rider = c.sort_values(by=['order_ids_points', 'rider_score_points', 'travel_distance_points'], ascending=[False, False, False]).round(2)
best_rider.query("`travel_distance_points` < 100 and `travel_distance_points` > 0.0 ")

best_rider.loc[(best_rider['order_ids_points'] <= 100), 'order_ids_points'] = best_rider['order_ids_points'] * 1.25
best_rider.loc[(best_rider['order_ids_points'] > 100) & (best_rider['order_ids_points'] <= 200), 'order_ids_points'] = best_rider['order_ids_points'] * 1.75
best_rider.loc[(best_rider['order_ids_points'] > 200) & (best_rider['order_ids_points'] <= 250), 'order_ids_points'] = best_rider['order_ids_points'] * 2.0
best_rider.loc[(best_rider['order_ids_points'] > 300) & (best_rider['order_ids_points'] <= 350), 'order_ids_points'] = best_rider['order_ids_points'] * 2.25
best_rider.loc[(best_rider['order_ids_points'] > 350) & (best_rider['order_ids_points'] <= 400), 'order_ids_points'] = best_rider['order_ids_points'] * 2.50
best_rider.loc[(best_rider['order_ids_points'] > 400), 'order_ids_points'] = best_rider['order_ids_points'] * 3

best_rider.loc[(best_rider['rider_score_points'] <= 4.00), 'rider_score_points'] = best_rider['rider_score_points'] * 50.00
best_rider.loc[(best_rider['rider_score_points'] > 4.00) & (best_rider['rider_score_points'] <= 4.05), 'rider_score_points'] = best_rider['rider_score_points'] * 100.00
best_rider.loc[(best_rider['rider_score_points'] > 4.05) & (best_rider['rider_score_points'] <= 4.10), 'rider_score_points'] = best_rider['rider_score_points'] * 150.00
best_rider.loc[(best_rider['rider_score_points'] > 4.10) & (best_rider['rider_score_points'] <= 4.15), 'rider_score_points'] = best_rider['rider_score_points'] * 200.00
best_rider.loc[(best_rider['rider_score_points'] > 4.15) & (best_rider['rider_score_points'] <= 4.25), 'rider_score_points'] = best_rider['rider_score_points'] * 250.00
best_rider.loc[(best_rider['rider_score_points'] > 4.25) & (best_rider['rider_score_points'] <= 5.0), 'rider_score_points'] = best_rider['rider_score_points'] * 300.00

best_rider['total_points'] = (best_rider['order_ids_points']+best_rider['rider_score_points']+best_rider['travel_distance_points'])

best_rider.sort_values(by=['total_points'], ascending=[False]).head(10)
# Out:
#                                   order_ids_points  rider_score_points  \
# user_id
# 8e37a68fab5f31a5e2c1b5f77c6bb9e5         2812.5000              1464.0
# 0a98cead98f3935ef3051e834a30419e         2274.7500              1485.0
# 406921adcca37705ef527b4246c12e83         2315.2500              1446.0
# ae06c34243f741e203e97c48eb42017b         1341.0000              1467.0
# a86c8d399be95a32f795a8a9887127b9         1302.0000               195.5
# ae06c34243f741e203e97c48eb62c195         2099.2500              1452.0
# 2ca81f8112b8c60af222ee2ed7287d4e         2279.8125              1482.0
# d2f1475850c213560abdec5deae2dc97         1422.0000              1401.0
# 406921adcca37705ef527b4246c1370e         2220.7500              1455.0
# 13cd660fbea6e3b6221aa0fc6fcb8f58         2067.1875              1437.0
#
#                                   travel_distance_points  total_points
# user_id
# 8e37a68fab5f31a5e2c1b5f77c6bb9e5                 2409.37     6685.8700
# ...

# %%
best_rider = best_rider.sort_values(by=['total_points'], ascending=[False]).head(11)
sns.barplot(x = best_rider.total_points, y = best_rider.index , data = best_rider)
# Out:
# <Axes: xlabel='total_points', ylabel='driver_id'>

# %%
new_df.dtypes
# Out:
# order_id                 object
# user_id                  object
# driver_id                object
# rider_score             float64
# driver_score            float64
# user_platform            object
# order_type               object
# travel_time_in_hours    float64
# travel_distance         float64
# dtype: object

# %%
a = new_df.groupby(['user_id']).agg({'order_id':'count', 'rider_score':'mean', 'travel_distance':'sum'})
a.sort_values(by=['order_id'], ascending=[False]).round(2)
# Out:
#                                   order_id  rider_score  travel_distance
# user_id
# ae06c34243f741e203e97c48eb42017b       447         4.90          2863.20
# a86c8d399be95a32f795a8a9887127b9       434         4.61          3241.50
# 8ed36e0e9dbf62743c06c09e5f7c1835       416         4.90          1001.70
# 8e37a68fab5f31a5e2c1b5f77c6bb9e5       375         4.94          2409.37
# 406921adcca37705ef527b4246c12e83       343         4.89          1917.51
# ...                                    ...          ...              ...
# 837f1b20121093bdceefd102a86785f0         1          NaN             2.10
# 837fafe7c928dce2d591f2b10227da8a         1         5.00             7.35
# 85a5e7c05506fa2e6ec863f6fef80462         1          NaN             2.31
# 85b7eabcf5d84e42dc7629b7d2f4f971         1         4.00             0.00
# ff5c924e0b630fd7c019a42340596fb0         1         5.00             6.22
#
# [1217 rows x 3 columns]

# %% [markdown]
# 1. Есть ли корреляция между типом заказа и тем, как клиент оценивает водителя?
# Ответ: Да, пользователи опаздывающие на заказ больше ставят плохие оценки водителям

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.barplot(data=new_df, errorbar=None, x="driver_score", y="order_type")
# Out:
# <Axes: xlabel='driver_score', ylabel='order_type'>

# %%
a = new_df.groupby(['order_type']).agg({'driver_score':'mean'})
a.sort_values(by=['driver_score'], ascending=[False]).round(2)
# Out:
#             driver_score
# order_type
# reserved            4.05
# asap                3.87
# delayed             1.67

# %% [markdown]
# 2. Есть ли корреляция между ответственностью клиента (оценками, которые выставляют
# ему водители) и платформой, с которой он делает заказ?
# Ответ: Да, пользователи заказывающие с web платформы менее ответственные

# %%
sns.barplot(data=new_df, errorbar=None, x="user_platform", y="rider_score")
# Out:
# <Axes: xlabel='user_platform', ylabel='rider_score'>

# %%
a = Sort.groupby(['user_platform']).agg({'rider_score':'mean'})
a.sort_values(by=['rider_score'], ascending=[False]).round(2)
# Out:
#                rider_score
# user_platform
# Android                5.0
# Wap                    5.0
# iPad                   5.0
# iPhone                 5.0
# web                    5.0

# %% [markdown]
# 3. Есть ли зависимость между продолжительностью поездки и типом заказа?
# Ответ: Нет, если delayed поездка длится в среднем 45 минут, в reserved 47, в asap 43.

# %%
sns.barplot(data=new_df, errorbar=None, x="order_type", y="travel_time_in_hours")
# Out:
# <Axes: xlabel='order_type', ylabel='travel_time_in_hours'>

# %%
a = Sort.groupby(['order_type']).agg({'travel_time_in_hours':'mean'})
a.sort_values(by=['travel_time_in_hours'], ascending=[False]).round(2)
# Out:
#             travel_time_in_hours
# order_type
# delayed                     0.75
# asap                        0.68
# reserved                    0.62

# %%
a = new_df.groupby(['order_type']).agg({'order_id':'count'})
b = a.sort_values(by=['order_id'], ascending=[False]).round(2)
b
# Out:
#             order_id
# order_type
# asap           10556
# reserved        6856
# delayed            5
