# %%
import pandas as pd
df = pd.read_csv("taxi_peru.csv", delimiter=';', encoding = "Windows-1251")
df
# Out:
#                              journey_id                           user_id  \
# 0      23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1      dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2      dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3      dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4      85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# ...                                 ...                               ...
# 23106  4a18ea5737ce0ffecaf20b305a0e2c86  8998bb370b5f0cec43a373adebba0c72
# 23107  f1e4317f2c17991dd90d1cd17ae0d399  5f8a6ffef0ea5df78a8ee890267b60ec
# 23108  1e44c0fd0a266c3719ff30410b257bce  c0ffb6f6cd801004dd8609c12277c2d1
# 23109  7073883383b89ad289e864022150cdd7  c0ffb6f6cd801004dd8609c12277c2d1
# 23110  b7dea45c3cc92b9efd5a4905e69ff9bf  c0ffb6f6cd801004dd8609c12277c2d1
#
#                               driver_id                           taxi_id  \
# ...

# %%
df.dtypes
# Out:
# journey_id           object
# user_id              object
# driver_id            object
# taxi_id              object
# icon                 object
# start_type           object
# start_at             object
# start_lat            object
# start_lon            object
# end_at               object
# end_lat              object
# end_lon              object
# end_state            object
# driver_start_lat     object
# driver_start_lon     object
# arrived_at           object
# source               object
# driver_score        float64
# rider_score         float64
# dtype: object

# %%
df = df[(df.end_state != 'not found') & (df.end_state != 'rider cancel') & (df.end_state != 'driver cancel')]
df
# Out:
#                              journey_id                           user_id  \
# 0      23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 4      85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# 5      2254715f0f569e3173ec61f16cbb8341  56772d544fdfa589a020a1ff894a86f7
# 6      12432d83b49393bf25164673212b8295  56772d544fdfa589a020a1ff894a86f7
# 7      2e51db3a8a77aa594aa686ff19fe6036  56772d544fdfa589a020a1ff894a86f7
# ...                                 ...                               ...
# 23105  a7b77e5e6e60dc427d96d8d22ac91032  35e7f74c2fbd27db816811036af892e5
# 23106  4a18ea5737ce0ffecaf20b305a0e2c86  8998bb370b5f0cec43a373adebba0c72
# 23107  f1e4317f2c17991dd90d1cd17ae0d399  5f8a6ffef0ea5df78a8ee890267b60ec
# 23108  1e44c0fd0a266c3719ff30410b257bce  c0ffb6f6cd801004dd8609c12277c2d1
# 23109  7073883383b89ad289e864022150cdd7  c0ffb6f6cd801004dd8609c12277c2d1
#
#                               driver_id                           taxi_id  \
# ...

# %%
Sort = df.query("`rider_score` > 4.0")
a = Sort.groupby(['user_id']).agg({'journey_id':'count', 'rider_score':'mean'})
a.sort_values(by=['journey_id', 'rider_score'], ascending=[False, False]).head(5)
# Out:
#                                   journey_id  rider_score
# user_id
# ae06c34243f741e203e97c48eb42017b         394          5.0
# 8ed36e0e9dbf62743c06c09e5f7c1835         365          5.0
# 406921adcca37705ef527b4246c12e83         312          5.0
# a86c8d399be95a32f795a8a9887127b9         284          5.0
# ae06c34243f741e203e97c48eb62c195         229          5.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17698 entries, 0 to 23109
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   journey_id        17698 non-null  object
#  1   user_id           17698 non-null  object
#  2   driver_id         17437 non-null  object
#  3   taxi_id           17437 non-null  object
#  4   icon              17698 non-null  object
#  5   start_type        17698 non-null  object
#  6   start_at          17698 non-null  object
#  7   start_lat         17698 non-null  object
#  8   start_lon         17698 non-null  object
#  9   end_at            17433 non-null  object
#  10  end_lat           17698 non-null  object
#  11  end_lon           17698 non-null  object
#  12  end_state         17686 non-null  object
#  13  driver_start_lat  17305 non-null  object
#  14  driver_start_lon  17305 non-null  object
#  15  arrived_at        17436 non-null  object
# ...

# %%
a = df.groupby(['user_id']).agg({'taxi_id':'count', 'driver_id':'count'})
a.sort_values(by=['taxi_id', 'driver_id'], ascending=[False, False]).head(5)
# Out:
#                                   taxi_id  driver_id
# user_id
# ae06c34243f741e203e97c48eb42017b      447        447
# a86c8d399be95a32f795a8a9887127b9      434        434
# 8ed36e0e9dbf62743c06c09e5f7c1835      416        416
# 8e37a68fab5f31a5e2c1b5f77c6bb9e5      376        376
# 406921adcca37705ef527b4246c12e83      343        343

# %%
df.taxi_id.unique()
# Out:
# array(['b12f4f09c783e29fe0d0ea624530db56',
#        '0accdd3aa5a322f4129fa20b53278c69',
#        'baacf396f773709519bbde35a585d91b',
#        'e1332f68e81526e498e4d845235baf80',
#        'd04f1a596fe4a582f48e6eb2f9e8cceb',
#        '406921adcca37705ef527b4246c10d2c',
#        '275052e660ff5672db6624c42b67ef9c',
#        'e84fda9c5df33f03c89b6923c362193f',
#        '3c6f537575929e983585ae9e8648d84a',
#        '031fea9628f9238b051a588085333504',
#        'bb1e39070cf5a2e2390f00f990d754c9',
#        '761737b194876dd53761a03c9591370b',
#        '992347d5c59f47b13b14442c6daca5ac',
#        '35a17a45aa341b999787fa5e50608f65',
#        'f622a9397b85b5c9c0ef938c5d592020',
#        '3d68e1172f35c1fbd06db5a1bc38c35f',
#        '275052e660ff5672db6624c42b69e770',
#        '294e869d187357cad25b8af65aa66c0a',
#        '3a9ca0965227dc470f30145e41c974ff',
#        '62c2e39787aa19cd2513901cf3b49643',
#        'b12f4f09c783e29fe0d0ea62452b9347',
#        '2a7979f6826bbbf4a061456c478a7326',
# ...
