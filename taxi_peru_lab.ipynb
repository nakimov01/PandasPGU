# %%
import pandas as pd
df = pd.read_csv("taxi_peru.csv", delimiter=';', encoding = "Windows-1251")
df.sort_values(by=['end_state'], ascending=[False])
# Out:
#                              journey_id                           user_id  \
# 23110  b7dea45c3cc92b9efd5a4905e69ff9bf  c0ffb6f6cd801004dd8609c12277c2d1
# 5742   b5821eaaa5d49fb2936ff5b0ffa79bba  760cafde3f1d33ceca82940e5230f9af
# 5765   bd321cca346778b979d594859ccc90f6  a86c8d399be95a32f795a8a9887127b9
# 5763   bd321cca346778b979d594859ccaa491  cf3a94138caddceb3209e4723638ef6f
# 19903  ab6ee368af1a9e1293acc0d14d1f69ce  a86c8d399be95a32f795a8a9887127b9
# ...                                 ...                               ...
# 5877   031fea9628f9238b051a58808531658e  9b474537c2b26020bb16aee19acacccf
# 6143   124dc2dbc4f79130bfa0b935778884ca  9b474537c2b26020bb16aee19acacccf
# 7033   395e6cdaabe3fe67d81014e862f2580b  901f7da979a892fafba72056b81a94af
# 8058   650f4aa44a581c90f7dd76ec82aa6040  ac3834b32de79bd97ee6bae75ed3ba99
# 8132   699c76a8203348961730e0164a78edd8  55a921582f7b88ef61a3d8e24f44b846
#
#                               driver_id                           taxi_id  \
# ...

# %%
a = df.groupby(['source']).agg({'user_id':'count',})
a.sort_values(by=[ 'user_id'], ascending=[False])
# Out:
#          user_id
# source
# iPhone      9741
# web         7631
# Android     4909
# iPad         571
# Wap          136
